# %% [markdown]
# # **Practicing Analytical Geometry**

# %%
# Dependencies and whatnot
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy as sp
import scipy.linal
import scipy.spatial
import numpy.linalg as LA
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Dot Product
